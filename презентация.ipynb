# %% [markdown]
# # Toolbox+Python+Latex: опыт автоматизации полевой рутины на примере ампари кора

# %% [markdown]
# # 1. Особенности доклада

# %% [markdown]
# -- методология, не теория
#
# -- сбор, обработка, хранение и упраление данными vs. анализ данных vs. лингвистический анализ

# %% [markdown]
# # 2. Disclaimer

# %% [markdown]
#  -- самоучка, опыт 2,5 года
#
#  -- возможны неточности в теримнологии, но терминология все равно будет
#
#  -- предложенные решения возможно не оптимальны
#
#  -- Toolbox  vs. FieldWorks

# %% [markdown]
# # 3. Старый подход к полевой работе

# %%
from IPython.display import Image
Image(r'c:\YandexDisk\ampari\schemes\toolbox+word.png')

# %% [markdown]
# # 4. Проблемы старого подхода

# %% [markdown]
# 1. Много времени занимает перенесение примеров из Toolbox’a в Word, даже с учетом макросов и проч. возможностей
#
# 2. Слабые возможности для анализа данных
#
# 3. Лингвистический анализ не успевает за данными
#
# 4. Из-за медленного анализа усложняется  процесс целенаправленного сбора данных

# %%
Image(r'c:\YandexDisk\ampari\schemes\toolbox+latex.png')

# %% [markdown]
# # 5. Set-up:Toolbox

# %% [markdown]
# Система управления лингвистиечскими данными: хранение, (полу)автоматическое глоссирование (формулы)
#
# .....примеры

# %% [markdown]
# # 6. Set-up: Jupyter (Python)

# %% [markdown]
# ⁃ Interactive development environment (IDE) для Python, Latex, SQL и др.
#
# ⁃ Стандарт Datascience
#
# ⁃ Позволяет трансформировать код с комментариями в полноценный html/pdf документ, презентацию

# %% [markdown]
# # 7. Set-up: Latex

# %% [markdown]
#  - MikTex, Xelatex  (Windows)
#  - Юникод щрифты (Doulos, Charis SIL)
#  - Tex Studio
#  - Jupyter (??)

# %% [markdown]
# # 8. Latex

# %% [markdown]
# Что это?
#
# ⁃ Язык разметки текста (cf. html, xml, Toolbox)
#
# ⁃ Интерпретатор языка разметки
#
# ⁃ Рендер pdf-документов
#
#
# Преимущества:
#
# ⁃ готовые шаблоны для статьей, монографий и пр.
#
# ⁃ нет «ручного» форматирования à la MS Word
#
# ⁃ специальные лингвистические модули
#
# ⁃ автоматизация проще
#
# Недостатки:
#
# ⁃ нужно себя перебороть: первое время кажется, что все долго, нелогично, не удобно)
#
# ⁃ Многие журналы требуют MS Word

# %% [markdown]
# # 9. Выводы

# %% [markdown]
# 1) Предложенное решение позволяет существенно уменьшить условную задержку между этапом сбора и обработки данных и появлением научного продукта (статья, хэндаут, монография)
#
# 2) Способствует направленному сбору данных с постоянной поддержкой аналитики
#
# 3) Дальнейшее сближение лингвистического инструментария и инструментария науки о данных
